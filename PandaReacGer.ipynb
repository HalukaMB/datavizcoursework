# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
CDU_data = pd.read_csv('First Analysis/Statuses_Ger/CDU_facebook_statuses.csv')
df1=pd.DataFrame(CDU_data)

# %%
SPD_data = pd.read_csv('First Analysis/Statuses_Ger/SPD_facebook_statuses.csv')
df2=pd.DataFrame(SPD_data)

# %%
linkspartei_data = pd.read_csv('First Analysis/Statuses_Ger/linkspartei_facebook_statuses.csv')
df3=pd.DataFrame(linkspartei_data)

# %%
B90DieGruenen_data = pd.read_csv('First Analysis/Statuses_Ger/B90DieGruenen_facebook_statuses.csv')
df4=pd.DataFrame(B90DieGruenen_data)

# %%
FDP_data = pd.read_csv('First Analysis/Statuses_Ger/FDP_facebook_statuses.csv')
df5=pd.DataFrame(FDP_data)

# %%
AFD_data = pd.read_csv('First Analysis/Statuses_Ger/alternativefuerde_facebook_statuses.csv')
df6=pd.DataFrame(AFD_data)

# %%
list=[]
for i in range(6):
    number=i+1
    el="df%d" %(number)
    print(el)
    list.append(el)
print(list)
# Out:
# df1
# df2
# df3
# df4
# df5
# df6
# ['df1', 'df2', 'df3', 'df4', 'df5', 'df6']

# %%
a=(str(list))
b=a.translate(str.maketrans({"'":None}))
print(type(a))
print(b)
# Out:
# <class 'str'>
# [df1, df2, df3, df4, df5, df6]

# %%
result=pd.concat([df1, df2, df3, df4, df5, df6])

# %%
print(result)
# Out:
#                             status_id  \
# 0       78502295414_10154525859700415
# 1       78502295414_10154523264550415
# 2       78502295414_10154521575520415
# 3       78502295414_10154517790455415
# 4       78502295414_10154517345910415
# 5       78502295414_10154517439585415
# 6       78502295414_10154517216725415
# 7       78502295414_10154515813185415
# 8       78502295414_10154515396380415
# 9       78502295414_10154512681765415
# 10      78502295414_10154512497025415
# 11      78502295414_10154510725830415
# 12      78502295414_10154510569380415
# 13      78502295414_10154509889765415
# 14      78502295414_10154507862930415
# 15      78502295414_10154507857020415
# 16      78502295414_10154505572310415
# 17      78502295414_10154505131735415
# 18      78502295414_10154504852600415
# 19      78502295414_10154504442140415
# 20      78502295414_10154502490185415
# 21      78502295414_10154499020920415
# 22      78502295414_10154496015405415
# ...

# %%
result.to_csv('ReacGer.csv')
