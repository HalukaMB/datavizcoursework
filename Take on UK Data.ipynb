# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
conservatives_data = pd.read_csv('conservatives_facebook_statuses.csv')
df1=pd.DataFrame(conservatives_data)

# %%
df1["Party"]="conservatives"
df1.head()
# Out:
#                       status_id  \
# 0  8807334278_10154876623519279
# 1  8807334278_10154865615464279
# 2  8807334278_10154840530464279
# 3  8807334278_10154823849619279
# 4  8807334278_10154822054359279
#
#                                       status_message             link_name  \
# 0                                                NaN           Theresa May
# 1  A vote for the Conservatives in the local elec...  Local elections 2017
# 2                                                NaN           Theresa May
# 3                                                NaN           Theresa May
# 4                                                NaN           Theresa May
#
#   status_type                                        status_link  \
# 0       video  https://www.facebook.com/TheresaMayOfficial/vi...
# 1        link  https://www.conservatives.com/sharethefacts/20...
# 2       video  https://www.facebook.com/TheresaMayOfficial/vi...
# ...

# %%
labour_data = pd.read_csv('labourparty_facebook_statuses.csv')
df2=pd.DataFrame(labour_data)

# %%
df2["Party"]="Labour"
df2.head()
# Out:
#                        status_id  \
# 0  25749647410_10154410254217411
# 1  25749647410_10154409637507411
# 2  25749647410_10154409052682411
# 3  25749647410_10154392888542411
# 4  25749647410_10154399502137411
#
#                                       status_message  \
# 0                                                NaN
# 1  Today we announced our plans for a real Living...
# 2  The Tories are taking our country backwards – ...
# 3  If you're not sure how differently Labour & th...
# 4  A staggering 1,240 Sure Start centres have bee...
#
#                                            link_name status_type  \
# 0                                      Jeremy Corbyn        link
# 1                                  www.labour.org.uk        link
# 2             Labour will invest in a better Britain       video
# 3  One child, two very different journeys through...        link
# 4                                                NaN       video
#
# ...

# %%
SNP_data = pd.read_csv('theSNP_facebook_statuses.csv')
df3=pd.DataFrame(SNP_data)
df3["Party"]="SNP"
df3.head()
# Out:
#                        status_id  \
# 0  77249349077_10155302127594078
# 1  77249349077_10155302182089078
# 2  77249349077_10155301312929078
# 3  77249349077_10155301468299078
# 4  77249349077_10155301274994078
#
#                                       status_message  \
# 0  🎥 Watch Alenka from Falkirk on why she support...
# 1  🎥 Don't miss our Party Election Broadcast for ...
# 2  🇺🇸 In the US, Nicola Sturgeon announced that V...
# 3  📊 Nicola Sturgeon is the only political leader...
# 4  📢 🇺🇸 Read Nicola Sturgeon on promoting Scotlan...
#
#                                            link_name status_type  \
# 0       Alenka from Falkirk on Scotland's Referendum       video
# 1                                    media.giphy.com        link
# 2                                    Timeline Photos       photo
# 3  Nicola Sturgeon enjoys 'highest approval ratin...        link
# 4                                    Nicola Sturgeon        link
#
# ...

# %%
libdems_data = pd.read_csv('libdems_facebook_statuses.csv')
df4=pd.DataFrame(libdems_data)
df4["Party"]="libdems"
df4.head()
# Out:
#                       status_id  \
# 0  5883973269_10155232771738270
# 1  5883973269_10155203160668270
# 2  5883973269_10155203155543270
# 3  5883973269_10155203184128270
# 4  5883973269_10155203171738270
#
#                                       status_message  \
# 0  Tim Farron has renewed his call for Theresa Ma...
# 1  "I have two sons aged 14 and 12 who were both ...
# 2  "I was brought up very much as a liberal (with...
# 3  "On 24 June 2016 everything changed. I have tw...
# 4  "I was born in 1945 whilst the war was still o...
#
#                                            link_name status_type  \
# 0  Tim Farron: Urgent humanitarian need to protec...        link
# 1                                    Timeline Photos       photo
# 2                                    Timeline Photos       photo
# 3                                    Timeline Photos       photo
# 4                                    Timeline Photos       photo
#
# ...

# %%
democraticunionistparty_data = pd.read_csv('democraticunionistparty_facebook_statuses.csv')
df5=pd.DataFrame(democraticunionistparty_data)
df5["Party"]="democraticunionist"
df5.head()
# Out:
#                           status_id  \
# 0  105732052794210_1564334313600636
# 1  105732052794210_1557166607650740
# 2  105732052794210_1554707111230023
# 3  105732052794210_1551434358223965
# 4  105732052794210_1550961558271245
#
#                                       status_message          link_name  \
# 0  Party press conference on the ongoing talks at...                NaN
# 1  Diane Dodds MEP addressing MEPs in Strasbourg ...        Diane Dodds
# 2  Coverage of our press conference at Stormont t...  Belfast Telegraph
# 3  Best wishes to Cllr Hogg as he prepares to lea...      Arlene Foster
# 4                                                NaN                NaN
#
#   status_type                                        status_link  \
# 0       video  https://www.facebook.com/democraticunionistpar...
# 1       video  https://www.facebook.com/DianedoddsMEP/videos/...
# 2       video  https://www.facebook.com/belfasttelegraph/vide...
# ...

# %%
sinnfein_data = pd.read_csv('sinnfein_facebook_statuses.csv')
df6=pd.DataFrame(sinnfein_data)
df6["Party"]="sinnfein"
df6.head()
# Out:
#                           status_id  \
# 0  148726998530273_1255083824561246
# 1  148726998530273_1254031857999776
# 2  148726998530273_1254037891332506
# 3  148726998530273_1252128874856741
# 4  148726998530273_1252067258196236
#
#                                       status_message  \
# 0  This young Irish boy was shot dead in his own ...
# 1  At a time when people are still struggling to ...
# 2  Sinn Féin MLA Michelle O'Neill has said there ...
# 3  "This is what democracy looks like" – Mary Lou...
# 4  The decision by ETA to complete the process of...
#
#                                            link_name status_type  \
# 0  Derry 15-year-old shot dead by British sniper ...        link
# 1  Sinn Féin TDs return politicians pay rises, ca...       video
# 2  No prospect of agreement if fundamental issues...       video
# 3           Mary Lou McDonald at Right2Water protest       video
# 4                 Adams welcomes ETA move on weapons       video
#
# ...

# %%
PlaidCymruWales_data = pd.read_csv('PlaidCymruWales_facebook_statuses.csv')
df7=pd.DataFrame(PlaidCymruWales_data)
df7["Party"]="PlaidCymruWales"
df7.head()
# Out:
#                        status_id  \
# 0  26416930992_10155030166385993
# 1  26416930992_10155030164310993
# 2  26416930992_10155029718405993
# 3  26416930992_10155026942125993
# 4  26416930992_10155019464815993
#
#                                       status_message  \
# 0  "Dylid gwrthod y cynigion am Stryd Womanby oni...
# 1  "The proposals for Womanby Street should be re...
# 2  'It's time that communities voted for a party ...
# 3                                                NaN
# 4  Not the most conventional of headlines by the ...
#
#                                            link_name status_type  \
# 0  AC y Blaid yn galw am warchod lleoliadau cerdd...        link
# 1  Plaid AM calls for protection of live music ve...        link
# 2                               Nasir Adam, Butetown       video
# 3                                      Steffan Lewis        link
# 4  Plaid Cymru's manifesto launch at Wrexham beer...        link
#
# ...

# %%
SDLP_data = pd.read_csv('SocialDemocraticLabourParty_facebook_statuses.csv')
df8=pd.DataFrame(SDLP_data)
df8["Party"]="SDLP"
df8.head()
# Out:
#                           status_id  \
# 0  111956985487415_1718383074844790
# 1  111956985487415_1717305984952499
# 2  111956985487415_1704246609591770
# 3  111956985487415_1704185809597850
# 4  111956985487415_1703395843010180
#
#                                       status_message  \
# 0  Every day we're hearing about more cuts to edu...
# 1  #OnThisDay 19 years ago the Good Friday Agreem...
# 2  Northern Ireland is the area of these islands ...
# 3  Did Paul Givan get a light touch after committ...
# 4  Tá an SDLP fíorbhródúil bheith ag obair ar son...
#
#                                            link_name status_type  \
# 0  Are children suffering the most from the polit...        link
# 1  Can the Good Friday Agreement help us with Bre...       video
# 2                                    Timeline Photos       photo
# 3  After 8 months silence, Stormont admits DUP's ...        link
# 4  Photos from Social Democratic and Labour Party...       photo
#
# ...

# %%
UKIP_data = pd.read_csv('UKIP_facebook_statuses.csv')
df9=pd.DataFrame(UKIP_data)
df9["Party"]="UKIP"
df9.head()
# Out:
#                           status_id  \
# 0  209101162445115_1426435600711659
# 1  209101162445115_1424381367583749
# 2  209101162445115_1423454097676476
# 3  209101162445115_1423321997689686
# 4  209101162445115_1422219537799932
#
#                                       status_message  \
# 0  UKIP Leader Paul Nuttall: "So while the cosy e...
# 1                                                NaN
# 2  This week, UKIP tabled around 10 amendments to...
# 3  Read UKIP Leader Paul Nuttall's take on the U....
# 4  Paul Nuttall, the UKIP leader has condemned th...
#
#                                            link_name status_type  \
# 0  NUTTALL: Oust Assad and Syria will be far more...        link
# 1                                   Paul Nuttall MEP        link
# 2                                 Nathan Gill AM MEP       video
# 3  What's worse than Syrian children dying? MORE ...        link
# 4                                                NaN      status
#
# ...

# %%
thegreenparty_data = pd.read_csv('thegreenparty_facebook_statuses.csv')
df10=pd.DataFrame(thegreenparty_data)
df10["Party"]="greenparty"
df10.head()
# Out:
#                        status_id  \
# 0  20995300784_10154369267115785
# 1  20995300784_10154368424715785
# 2  20995300784_10154359557220785
# 3  20995300784_10154359293985785
# 4  20995300784_10154357166440785
#
#                                       status_message  \
# 0                                                NaN
# 1  Secret documents reveal that the Government is...
# 2  Today we've launched our local elections campa...
# 3  Last night Jonathan Bartley spoke on BBC Quest...
# 4  Tonight on BBC Question Time, Jonathan Bartley...
#
#                                            link_name status_type  \
# 0                                   Jonathan Bartley        link
# 1  Government to 'scale down' climate change meas...        link
# 2                                    Timeline Photos       photo
# 3                                                NaN       video
# 4                  Jonathan Bartley on Question Time       video
#
# ...

# %%
ulsterunionistparty_data = pd.read_csv('ulsterunionistparty_facebook_statuses.csv')
df11=pd.DataFrame(ulsterunionistparty_data)
df11["Party"]="ulsterunionist"
df11.head()
# Out:
#                         status_id  \
# 0  107584191543_10155079315341544
# 1  107584191543_10155079298991544
# 2  107584191543_10155072279246544
# 3  107584191543_10155071798796544
# 4  107584191543_10155060013756544
#
#                                       status_message  \
# 0  Support the Hyde Park Justice Campaign! Follow...
# 1  Danny Kinahan MP backs Hyde Park Justice Campa...
# 2                                                NaN
# 3  The new Leader of the Ulster Unionist Party, R...
# 4  Jim Nicholson MEP tells EU`s top Brexit negoti...
#
#                                            link_name status_type  \
# 0              Justice for Victims of Hyde Park Bomb        link
# 1  Hyde Park bomb justice campaign backed by Nort...        link
# 2                       2017 AGM & Spring Conference       photo
# 3                                        Robin Swann       video
# 4  EU's Barnier 'twiddles on phone' in Brexit deb...        link
#
# ...

# %%
list=[]
for i in range(11):
    number=i+1
    el="df%d" %(number)
    print(el)
    list.append(el)
print(list)
# Out:
# df1
# df2
# df3
# df4
# df5
# df6
# df7
# df8
# df9
# df10
# df11
# ['df1', 'df2', 'df3', 'df4', 'df5', 'df6', 'df7', 'df8', 'df9', 'df10', 'df11']

# %%
a=(str(list))
b=a.translate(str.maketrans({"'":None}))
print(type(a))
print(b)
# Out:
# <class 'str'>
# [df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11]

# %%
result=pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11])

# %%
print(result)
# Out:
#                           status_id  \
# 0      8807334278_10154876623519279
# 1      8807334278_10154865615464279
# 2      8807334278_10154840530464279
# 3      8807334278_10154823849619279
# 4      8807334278_10154822054359279
# 5      8807334278_10154815215009279
# 6      8807334278_10154807268109279
# 7      8807334278_10154807048109279
# 8      8807334278_10154799212859279
# 9      8807334278_10154796267084279
# 10     8807334278_10154782032609279
# 11     8807334278_10154779229229279
# 12     8807334278_10154775601784279
# 13     8807334278_10154764286799279
# 14     8807334278_10154759415004279
# 15     8807334278_10154759320439279
# 16     8807334278_10154745628249279
# 17     8807334278_10154743534804279
# 18     8807334278_10154727701384279
# 19     8807334278_10154720550899279
# 20     8807334278_10154704485709279
# 21     8807334278_10154697922854279
# 22     8807334278_10154682734559279
# 23     8807334278_10154680244384279
# 24     8807334278_10154666531234279
# ...

# %%
result.to_csv('example.csv')
